# %%
import numpy as np
import pandas as pd
import altair as alt
unemploymentData = pd.read_csv("UNRATE.csv")
dogeData = pd.read_csv("DOGE-USD.csv")

# %%
dogeData
# Out:
#            Date      Open      High       Low     Close  Adj Close  \
# 0    2021-01-01  0.004681  0.005685  0.004615  0.005685   0.005685
# 1    2021-01-02  0.005686  0.013698  0.005584  0.010615   0.010615
# 2    2021-01-03  0.010602  0.013867  0.009409  0.009771   0.009771
# 3    2021-01-04  0.009785  0.011421  0.007878  0.009767   0.009767
# 4    2021-01-05  0.009767  0.010219  0.008972  0.009920   0.009920
# ..          ...       ...       ...       ...       ...        ...
# 111  2021-04-22  0.305990  0.308757  0.256276  0.260967   0.260967
# 112  2021-04-23  0.261023  0.268378  0.163669  0.248509   0.248509
# 113  2021-04-24  0.249544  0.289390  0.229891  0.270212   0.270212
# 114  2021-04-25  0.269789  0.288771  0.226301  0.251111   0.251111
# 115  2021-04-26  0.248415  0.279703  0.248415  0.265506   0.265506
#
#           Volume
# 0      228961515
# 1     3421562680
# 2     2707003608
# 3     1372398979
# 4      687256067
# ..           ...
# 111  11879823706
# ...

# %%
unemploymentData
# Out:
#           DATE  UNRATE
# 0   2019-01-01     4.0
# 1   2019-02-01     3.8
# 2   2019-03-01     3.8
# 3   2019-04-01     3.7
# 4   2019-05-01     3.7
# 5   2019-06-01     3.6
# 6   2019-07-01     3.6
# 7   2019-08-01     3.7
# 8   2019-09-01     3.5
# 9   2019-10-01     3.6
# 10  2019-11-01     3.6
# 11  2019-12-01     3.6
# 12  2020-01-01     3.5
# 13  2020-02-01     3.5
# 14  2020-03-01     4.4
# 15  2020-04-01    14.8
# 16  2020-05-01    13.3
# 17  2020-06-01    11.1
# 18  2020-07-01    10.2
# 19  2020-08-01     8.4
# 20  2020-09-01     7.8
# 21  2020-10-01     6.9
# 22  2020-11-01     6.7
# 23  2020-12-01     6.7
# 24  2021-01-01     6.3
# 25  2021-02-01     6.2
# 26  2021-03-01     6.0

# %%
#unemploymentData
unemploymentChart = alt.Chart(unemploymentData).mark_area().encode(
    x=alt.X("DATE",title="Date",timeUnit="yearmonth"),
    y="UNRATE",
    tooltip=["yearmonth(DATE)","UNRATE"])

# %%
#dogeData
dogeChart = alt.Chart(dogeData).mark_area().encode(
    x=alt.X("Date",title="Date",timeUnit="monthdate"),
    y="Close",
    tooltip=["yearmonth(Date)","Close"]).properties(width=900,height=300)
dogeChart
# Out:
# alt.Chart(...)

# %%
alt.vconcat(unemploymentChart,dogeChart)
# Out:
# alt.VConcatChart(...)

# %%
gasPrices = pd.read_csv("GASREGW (1).csv")
gasChart = alt.Chart(gasData).mark_area().encode(
    x=alt.X("DATE",title="Date",timeUnit="yearmonthdate"),
    y=alt.Y("GASREGW",title="Regular All Formations Gas Price")).properties(
    width=900,
    height=300)

# %%
gasChart
# Out:
# alt.Chart(...)

# %%
moreDogeData = pd.read_csv("DOGE_USD_2020-04-26_2021-04-25-CoinDesk.csv")
alt.Chart(moreDogeData).mark_area().encode(
    x=alt.X("Date",title="Date",timeUnit="yearmonthdate"),
    y=alt.Y("Closing Price (USD)"))
# Out:
# alt.Chart(...)

# %%
moreDogeData
# Out:
#     Currency        Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0       DOGE  2020-04-26             0.002432        0.002125        0.002448
# 1       DOGE  2020-04-27             0.002351        0.002432        0.002441
# 2       DOGE  2020-04-28             0.002327        0.002353        0.002386
# 3       DOGE  2020-04-29             0.002525        0.002327        0.002572
# 4       DOGE  2020-04-30             0.002456        0.002525        0.002705
# ..       ...         ...                  ...             ...             ...
# 360     DOGE  2021-04-21             0.307960        0.317723        0.347929
# 361     DOGE  2021-04-22             0.268338        0.306176        0.309230
# 362     DOGE  2021-04-23             0.239144        0.260826        0.269405
# 363     DOGE  2021-04-24             0.271423        0.250250        0.291160
# 364     DOGE  2021-04-25             0.247978        0.270788        0.288426
#
#      24h Low (USD)
# ...

# %%
gasChart.properties()
# Out:
# alt.Chart(...)

# %%
gasData = pd.read_csv("GASREGW (1).csv")

# %%
# Out:
#           DATE  GASREGW
# 0   2019-08-05    2.688
# 1   2019-08-12    2.624
# 2   2019-08-19    2.598
# 3   2019-08-26    2.574
# 4   2019-09-02    2.563
# ..         ...      ...
# 85  2021-03-22    2.865
# 86  2021-03-29    2.852
# 87  2021-04-05    2.857
# 88  2021-04-12    2.849
# 89  2021-04-19    2.855
#
# [90 rows x 2 columns]
